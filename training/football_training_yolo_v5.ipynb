# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="nlwl5GCHDngWYc9pJgHG")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\nacho\\Documents\\Football_Analysis_CV\\training\\football-players-detection-1'

# %%
import shutil

shutil.move("football-players-detection-1/train",
            "football-players-detection-1/football-players-detection-1/train")

shutil.move("football-players-detection-1/test",
            "football-players-detection-1/football-players-detection-1/train")

shutil.move("football-players-detection-1/valid",
            "football-players-detection-1/football-players-detection-1/train")
# Out:
# 'football-players-detection-1/football-players-detection-1/train\\valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x data={dataset.location}/data.yaml epochs=100 imgsz=640
